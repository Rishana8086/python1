# %%
#int the colors in set1 but not in ser2
set1={"yellow","Red","purple","indigo"}
set2={"Green","Maroon","yellow"}
diff=set1-set2
print("The colors in a but not b is;",diff)
# Out:
# The colors in a but not b is; {'purple', 'indigo', 'Red'}

# %%
#all the color in set1 and color set2 
set1={"yellow","Red","purple","Indigo"}
set2={"Green","Maroon","yellow"}
union=set1.union(set2)
print("The colors in set1 and set2 combined is:",union)
# Out:
# The colors in set1 and set2 combined is: {'purple', 'Green', 'Maroon', 'yellow', 'Indigo', 'Red'}
