# %%
#Reverse a given srting
s=input("Enter a string:")
new_string=s[-1]+s[1:-1]+s[0]
print("New string is:",new_string)
# Out:
# Enter a string:python
# New string is: nythop

# %%
#String made of first 2 and the last 2 char from a string
s=input("Enter a string:")
new_string=s[0:3]+s[-2::1]
print("New sreing is:",new_string)
# Out:
# Enter a string:Engineer
# New sreing is: Enger

# %%
#creat astring separated withscore from two string by separating the character at position 1
s1=input()
